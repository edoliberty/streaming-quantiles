# %%
from stairwaytoheaven import StairwayToHeaven as sketch

# %%
from math import inf

k = 8
n = 30
s = sketch(k)
print(f'Boxes = {s.items}')
print(f'Heights = {s.get_heights()}')
print('n =', 0)
for i,x in enumerate(range(n,0,-1)):
    print('-'*80)
    print(f'Inserting value x = {x}')
    pop_index = s.update(x)
    if pop_index:
        print(f'Merged boxes {pop_index-1} and {pop_index}')
    else:
        print(f'Merged no boxes')
    print(f'Boxes = {s.items}')
    hs = s.get_heights()
    assert(max(hs)==hs[0])
    print(f'Heights = {hs}')
    print('n =', i+1)
# Out:
# Boxes = [[-inf, inf, 0, 0]]
# Heights = [0]
# n = 0
# --------------------------------------------------------------------------------
# Inserting value x = 30
# Merged no boxes
# Boxes = [[-inf, 30, 0, 0], [30, inf, 1, 1]]
# Heights = [0, 0]
# n = 1
# --------------------------------------------------------------------------------
# Inserting value x = 29
# Merged no boxes
# Boxes = [[-inf, 29, 0, 0], [29, 30, 1, 1], [30, inf, 2, 2]]
# Heights = [0, 0, 0]
# n = 2
# --------------------------------------------------------------------------------
# Inserting value x = 28
# Merged no boxes
# Boxes = [[-inf, 28, 0, 0], [28, 29, 1, 1], [29, 30, 2, 2], [30, inf, 3, 3]]
# Heights = [0, 0, 0, 0]
# n = 3
# --------------------------------------------------------------------------------
# Inserting value x = 27
# Merged no boxes
# Boxes = [[-inf, 27, 0, 0], [27, 28, 1, 1], [28, 29, 2, 2], [29, 30, 3, 3], [30, inf, 4, 4]]
# Heights = [0, 0, 0, 0, 0]
# n = 4
# --------------------------------------------------------------------------------
# Inserting value x = 26
# Merged no boxes
# Boxes = [[-inf, 26, 0, 0], [26, 27, 1, 1], [27, 28, 2, 2], [28, 29, 3, 3], [29, 30, 4, 4], [30, inf, 5, 5]]
# Heights = [0, 0, 0, 0, 0, 0]
# n = 5
# --------------------------------------------------------------------------------
# Inserting value x = 25
# Merged no boxes
# Boxes = [[-inf, 25, 0, 0], [25, 26, 1, 1], [26, 27, 2, 2], [27, 28, 3, 3], [28, 29, 4, 4], [29, 30, 5, 5], [30, inf, 6, 6]]
# Heights = [0, 0, 0, 0, 0, 0, 0]
# n = 6
# --------------------------------------------------------------------------------
# Inserting value x = 24
# Merged no boxes
# Boxes = [[-inf, 24, 0, 0], [24, 25, 1, 1], [25, 26, 2, 2], [26, 27, 3, 3], [27, 28, 4, 4], [28, 29, 5, 5], [29, 30, 6, 6], [30, inf, 7, 7]]
# Heights = [0, 0, 0, 0, 0, 0, 0, 0]
# n = 7
# --------------------------------------------------------------------------------
# Inserting value x = 23
# Merged boxes 0 and 1
# Boxes = [[-inf, 24, 0, 1], [24, 25, 2, 2], [25, 26, 3, 3], [26, 27, 4, 4], [27, 28, 5, 5], [28, 29, 6, 6], [29, 30, 7, 7], [30, inf, 8, 8]]
# Heights = [1, 0, 0, 0, 0, 0, 0, 0]
# n = 8
# --------------------------------------------------------------------------------
# Inserting value x = 22
# Merged boxes 2 and 3
# Boxes = [[-inf, 22, 0, 1], [22, 24, 1, 2], [24, 26, 3, 4], [26, 27, 5, 5], [27, 28, 6, 6], [28, 29, 7, 7], [29, 30, 8, 8], [30, inf, 9, 9]]
# Heights = [1, 1, 1, 0, 0, 0, 0, 0]
# n = 9
# --------------------------------------------------------------------------------
# Inserting value x = 21
# Merged boxes 4 and 5
# Boxes = [[-inf, 21, 0, 1], [21, 22, 1, 2], [22, 24, 2, 3], [24, 26, 4, 5], [26, 28, 6, 7], [28, 29, 8, 8], [29, 30, 9, 9], [30, inf, 10, 10]]
# Heights = [1, 1, 1, 1, 1, 0, 0, 0]
# n = 10
# --------------------------------------------------------------------------------
# Inserting value x = 20
# Merged boxes 6 and 7
# Boxes = [[-inf, 20, 0, 1], [20, 21, 1, 2], [21, 22, 2, 3], [22, 24, 3, 4], [24, 26, 5, 6], [26, 28, 7, 8], [28, 30, 9, 10], [30, inf, 11, 11]]
# Heights = [1, 1, 1, 1, 1, 1, 1, 0]
# n = 11
# --------------------------------------------------------------------------------
# Inserting value x = 19
# Merged boxes 0 and 1
# Boxes = [[-inf, 20, 0, 2], [20, 21, 2, 3], [21, 22, 3, 4], [22, 24, 4, 5], [24, 26, 6, 7], [26, 28, 8, 9], [28, 30, 10, 11], [30, inf, 12, 12]]
# Heights = [2, 1, 1, 1, 1, 1, 1, 0]
# n = 12
# --------------------------------------------------------------------------------
# Inserting value x = 18
# Merged boxes 2 and 3
# Boxes = [[-inf, 18, 0, 2], [18, 20, 1, 3], [20, 22, 3, 5], [22, 24, 5, 6], [24, 26, 7, 8], [26, 28, 9, 10], [28, 30, 11, 12], [30, inf, 13, 13]]
# Heights = [2, 2, 2, 1, 1, 1, 1, 0]
# n = 13
# --------------------------------------------------------------------------------
# Inserting value x = 17
# Merged boxes 7 and 8
# Boxes = [[-inf, 17, 0, 2], [17, 18, 1, 3], [18, 20, 2, 4], [20, 22, 4, 6], [22, 24, 6, 7], [24, 26, 8, 9], [26, 28, 10, 11], [28, inf, 12, 14]]
# Heights = [2, 2, 2, 2, 1, 1, 1, 2]
# n = 14
# --------------------------------------------------------------------------------
# Inserting value x = 16
# Merged boxes 0 and 1
# Boxes = [[-inf, 17, 0, 3], [17, 18, 2, 4], [18, 20, 3, 5], [20, 22, 5, 7], [22, 24, 7, 8], [24, 26, 9, 10], [26, 28, 11, 12], [28, inf, 13, 15]]
# Heights = [3, 2, 2, 2, 1, 1, 1, 2]
# n = 15
# --------------------------------------------------------------------------------
# Inserting value x = 15
# Merged boxes 2 and 3
# Boxes = [[-inf, 15, 0, 3], [15, 17, 1, 4], [17, 20, 3, 6], [20, 22, 6, 8], [22, 24, 8, 9], [24, 26, 10, 11], [26, 28, 12, 13], [28, inf, 14, 16]]
# Heights = [3, 3, 3, 2, 1, 1, 1, 2]
# n = 16
# --------------------------------------------------------------------------------
# Inserting value x = 14
# Merged boxes 4 and 5
# Boxes = [[-inf, 14, 0, 3], [14, 15, 1, 4], [15, 17, 2, 5], [17, 20, 4, 7], [20, 24, 7, 10], [24, 26, 11, 12], [26, 28, 13, 14], [28, inf, 15, 17]]
# Heights = [3, 3, 3, 3, 3, 1, 1, 2]
# n = 17
# --------------------------------------------------------------------------------
# Inserting value x = 13
# Merged boxes 6 and 7
# Boxes = [[-inf, 13, 0, 3], [13, 14, 1, 4], [14, 15, 2, 5], [15, 17, 3, 6], [17, 20, 5, 8], [20, 24, 8, 11], [24, 28, 12, 15], [28, inf, 16, 18]]
# Heights = [3, 3, 3, 3, 3, 3, 3, 2]
# n = 18
# --------------------------------------------------------------------------------
# Inserting value x = 12
# Merged boxes 0 and 1
# Boxes = [[-inf, 13, 0, 4], [13, 14, 2, 5], [14, 15, 3, 6], [15, 17, 4, 7], [17, 20, 6, 9], [20, 24, 9, 12], [24, 28, 13, 16], [28, inf, 17, 19]]
# Heights = [4, 3, 3, 3, 3, 3, 3, 2]
# n = 19
# --------------------------------------------------------------------------------
# Inserting value x = 11
# Merged boxes 2 and 3
# Boxes = [[-inf, 11, 0, 4], [11, 13, 1, 5], [13, 15, 3, 7], [15, 17, 5, 8], [17, 20, 7, 10], [20, 24, 10, 13], [24, 28, 14, 17], [28, inf, 18, 20]]
# Heights = [4, 4, 4, 3, 3, 3, 3, 2]
# n = 20
# --------------------------------------------------------------------------------
# Inserting value x = 10
# Merged boxes 0 and 1
# Boxes = [[-inf, 11, 0, 5], [11, 13, 2, 6], [13, 15, 4, 8], [15, 17, 6, 9], [17, 20, 8, 11], [20, 24, 11, 14], [24, 28, 15, 18], [28, inf, 19, 21]]
# Heights = [5, 4, 4, 3, 3, 3, 3, 2]
# n = 21
# --------------------------------------------------------------------------------
# Inserting value x = 9
# Merged boxes 3 and 4
# Boxes = [[-inf, 9, 0, 5], [9, 11, 1, 6], [11, 13, 3, 7], [13, 17, 5, 10], [17, 20, 9, 12], [20, 24, 12, 15], [24, 28, 16, 19], [28, inf, 20, 22]]
# Heights = [5, 5, 4, 5, 3, 3, 3, 2]
# n = 22
# --------------------------------------------------------------------------------
# Inserting value x = 8
# Merged boxes 0 and 1
# Boxes = [[-inf, 9, 0, 6], [9, 11, 2, 7], [11, 13, 4, 8], [13, 17, 6, 11], [17, 20, 10, 13], [20, 24, 13, 16], [24, 28, 17, 20], [28, inf, 21, 23]]
# Heights = [6, 5, 4, 5, 3, 3, 3, 2]
# n = 23
# --------------------------------------------------------------------------------
# Inserting value x = 7
# Merged boxes 2 and 3
# Boxes = [[-inf, 7, 0, 6], [7, 9, 1, 7], [9, 13, 3, 9], [13, 17, 7, 12], [17, 20, 11, 14], [20, 24, 14, 17], [24, 28, 18, 21], [28, inf, 22, 24]]
# Heights = [6, 6, 6, 5, 3, 3, 3, 2]
# n = 24
# --------------------------------------------------------------------------------
# Inserting value x = 6
# Merged boxes 5 and 6
# Boxes = [[-inf, 6, 0, 6], [6, 7, 1, 7], [7, 9, 2, 8], [9, 13, 4, 10], [13, 17, 8, 13], [17, 24, 12, 18], [24, 28, 19, 22], [28, inf, 23, 25]]
# Heights = [6, 6, 6, 6, 5, 6, 3, 2]
# n = 25
# --------------------------------------------------------------------------------
# Inserting value x = 5
# Merged boxes 7 and 8
# Boxes = [[-inf, 5, 0, 6], [5, 6, 1, 7], [6, 7, 2, 8], [7, 9, 3, 9], [9, 13, 5, 11], [13, 17, 9, 14], [17, 24, 13, 19], [24, inf, 20, 26]]
# Heights = [6, 6, 6, 6, 6, 5, 6, 6]
# n = 26
# --------------------------------------------------------------------------------
# Inserting value x = 4
# Merged boxes 0 and 1
# Boxes = [[-inf, 5, 0, 7], [5, 6, 2, 8], [6, 7, 3, 9], [7, 9, 4, 10], [9, 13, 6, 12], [13, 17, 10, 15], [17, 24, 14, 20], [24, inf, 21, 27]]
# Heights = [7, 6, 6, 6, 6, 5, 6, 6]
# n = 27
# --------------------------------------------------------------------------------
# Inserting value x = 3
# Merged boxes 2 and 3
# Boxes = [[-inf, 3, 0, 7], [3, 5, 1, 8], [5, 7, 3, 10], [7, 9, 5, 11], [9, 13, 7, 13], [13, 17, 11, 16], [17, 24, 15, 21], [24, inf, 22, 28]]
# Heights = [7, 7, 7, 6, 6, 5, 6, 6]
# n = 28
# --------------------------------------------------------------------------------
# Inserting value x = 2
# Merged boxes 0 and 1
# Boxes = [[-inf, 3, 0, 8], [3, 5, 2, 9], [5, 7, 4, 11], [7, 9, 6, 12], [9, 13, 8, 14], [13, 17, 12, 17], [17, 24, 16, 22], [24, inf, 23, 29]]
# Heights = [8, 7, 7, 6, 6, 5, 6, 6]
# n = 29
# --------------------------------------------------------------------------------
# Inserting value x = 1
# Merged boxes 3 and 4
# Boxes = [[-inf, 1, 0, 8], [1, 3, 1, 9], [3, 5, 3, 10], [5, 9, 5, 13], [9, 13, 9, 15], [13, 17, 13, 18], [17, 24, 17, 23], [24, inf, 24, 30]]
# Heights = [8, 8, 7, 8, 6, 5, 6, 6]
# n = 30
